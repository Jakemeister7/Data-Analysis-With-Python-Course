# %% [markdown]
# <a href="https://colab.research.google.com/github/Jakemeister7/Data-Analysis-With-Python-Course/blob/main/Pandas_9_Functions_and_Sorting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pandas - Functions and Sorting

# %%
import pandas as pd
import numpy as np

# %%
# Create Dataframe
stuff = {
    'Corporation':["Apple", "Google", "Meta", "Apple", "Google", "Meta"],
    'Employees':['John', 'April', 'Wes', 'Aspen', 'Beth', 'Steph'],
    'Salary':[200, 220, 190, 130, 120, 150]}
my_df = pd.DataFrame(stuff)
my_df
# Out:
#   Corporation Employees  Salary
# 0       Apple      John     200
# 1      Google     April     220
# 2        Meta       Wes     190
# 3       Apple     Aspen     130
# 4      Google      Beth     120
# 5        Meta     Steph     150

# %%
# Create Function to change $ to thousands
def times1000(x):
  return x * 1000

# %%
# Apply the function
my_df['Salary'].apply(times1000)
# Out:
# 0    200000
# 1    220000
# 2    190000
# 3    130000
# 4    120000
# 5    150000
# Name: Salary, dtype: int64

# %%
# Format it nicer with decimals
def times1000(x):
  return format(x * 1000, ",d")

# %%
my_df['Salary'].apply(times1000)
# Out:
# 0    200,000
# 1    220,000
# 2    190,000
# 3    130,000
# 4    120,000
# 5    150,000
# Name: Salary, dtype: object

# %%
# Make it into a dataframe
pd.DataFrame(my_df['Salary'].apply(times1000))
# Out:
#     Salary
# 0  200,000
# 1  220,000
# 2  190,000
# 3  130,000
# 4  120,000
# 5  150,000

# %%
# Add the new data to the old dataframe
my_df["Salary"] = my_df['Salary'].apply(times1000)
my_df
# Out:
#   Corporation Employees   Salary
# 0       Apple      John  200,000
# 1      Google     April  220,000
# 2        Meta       Wes  190,000
# 3       Apple     Aspen  130,000
# 4      Google      Beth  120,000
# 5        Meta     Steph  150,000

# %%
# Add last name to names
def namer(x):
  if x == "John":
    return "John Elder"
  elif x == "April":
    return "April Elder"
  else:
    return x

# %%
# Apply it
my_df["Employees"].apply(namer)
# Out:
# 0     John Elder
# 1    April Elder
# 2            Wes
# 3          Aspen
# 4           Beth
# 5          Steph
# Name: Employees, dtype: object

# %%
# Use Lambdas inline
my_df['Salary'].apply(lambda x: format(int(x.replace(',', '')) * 1000, ',d'))
# Out:
# 0    200,000,000,000
# 1    220,000,000,000
# 2    190,000,000,000
# 3    130,000,000,000
# 4    120,000,000,000
# 5    150,000,000,000
# Name: Salary, dtype: object

# %%
# Make dataframe
pd.DataFrame(my_df["Salary"].apply(lambda x: format(int(x.replace(',', '')) * 1000, ',d')))
# Out:
#             Salary
# 0  200,000,000,000
# 1  220,000,000,000
# 2  190,000,000,000
# 3  130,000,000,000
# 4  120,000,000,000
# 5  150,000,000,000

# %%
# Append that stuff back to original dataframe
my_df['Salary'] = my_df['Salary'].apply(lambda x: format(int(x.replace(',', '')) * 1000, ',d'))
my_df
# Out:
#   Corporation Employees           Salary
# 0       Apple      John  200,000,000,000
# 1      Google     April  220,000,000,000
# 2        Meta       Wes  190,000,000,000
# 3       Apple     Aspen  130,000,000,000
# 4      Google      Beth  120,000,000,000
# 5        Meta     Steph  150,000,000,000

# %%
# Apply Functions to multiple columns (corp and emps)
def names(x):
  return f'Codemy: {x}'

# %%
# Apply To Two Columns
my_df[["Corporation", "Employees"]].apply(names)
# Out:
# Corporation    Codemy: 0     Apple\n1    Google\n2      Meta\...
# Employees      Codemy: 0     John\n1    April\n2      Wes\n3 ...
# dtype: object

# %%
# Append to Current DataFrame
pd.DataFrame(my_df[["Corporation", "Employees"]].apply(names))
# Out:
#                                                              0
# Corporation  Codemy: 0     Apple\n1    Google\n2      Meta\...
# Employees    Codemy: 0     John\n1    April\n2      Wes\n3 ...

# %%
# Sort Salaries from lowest to highest
my_df
# Out:
#   Corporation Employees           Salary
# 0       Apple      John  200,000,000,000
# 1      Google     April  220,000,000,000
# 2        Meta       Wes  190,000,000,000
# 3       Apple     Aspen  130,000,000,000
# 4      Google      Beth  120,000,000,000
# 5        Meta     Steph  150,000,000,000

# %%
# Sort Salaries from Highest to Lowest Descending
my_df.sort_values('Salary', ascending=False, inplace=True)
# Out:
#   Corporation Employees           Salary
# 1      Google     April  220,000,000,000
# 0       Apple      John  200,000,000,000
# 2        Meta       Wes  190,000,000,000
# 5        Meta     Steph  150,000,000,000
# 3       Apple     Aspen  130,000,000,000
# 4      Google      Beth  120,000,000,000

# %%
# Not Permanent without inplace=True
my_df
# Out:
#   Corporation Employees           Salary
# 1      Google     April  220,000,000,000
# 0       Apple      John  200,000,000,000
# 2        Meta       Wes  190,000,000,000
# 5        Meta     Steph  150,000,000,000
# 3       Apple     Aspen  130,000,000,000
# 4      Google      Beth  120,000,000,000

# %%
# Sort Strings Alphabetically Ascending A to Z
my_df.sort_values('Corporation', inplace=True)
my_df
# Out:
#   Corporation Employees           Salary
# 0       Apple      John  200,000,000,000
# 3       Apple     Aspen  130,000,000,000
# 4      Google      Beth  120,000,000,000
# 1      Google     April  220,000,000,000
# 2        Meta       Wes  190,000,000,000
# 5        Meta     Steph  150,000,000,000

# %%
# Sort Strings Alphabetically Descending Z to A
my_df.sort_values("Corporation", ascending=False)
my_df
# Out:
#   Corporation Employees           Salary
# 2        Meta       Wes  190,000,000,000
# 5        Meta     Steph  150,000,000,000
# 0       Apple      John  200,000,000,000
# 4      Google      Beth  120,000,000,000
# 3       Apple     Aspen  130,000,000,000
# 1      Google     April  220,000,000,000
