# %% [markdown]
# <a href="https://colab.research.google.com/github/Jakemeister7/Data-Analysis-With-Python-Course/blob/main/Matplotlib_2_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Matplotlib - Charts and Graphs

# %%
import pandas as pd
import numpy as np
from numpy.random import randn
# %matplotlib inline

# %%
# Create Random Number DataFrame
my_df = pd.DataFrame(randn(20, 4), columns=["Mon", "Tues", "Wed", "Thur"])
my_df
# Out:
#          Mon      Tues       Wed      Thur
# 0   0.387861  1.533813 -0.643676  0.902697
# 1   1.321448  0.097830  1.437297 -1.003669
# 2   1.131620 -2.223163  0.871924  0.466549
# 3  -0.927507  1.731498 -1.849792  0.871138
# 4   1.132569 -1.524331 -0.432400 -0.242512
# 5  -0.262751 -0.266345 -2.562374 -0.140701
# 6  -0.280265  0.314784 -0.268612 -0.848550
# 7   0.170934 -0.720509 -1.565238 -0.499777
# 8   0.392644 -0.693373 -0.680627 -0.251938
# 9  -0.517413  1.031422  0.146290  1.272384
# 10 -0.941204  1.690526  0.305151  0.201639
# 11  0.110380  0.714161  0.459879 -0.546776
# 12 -2.076575 -1.733942 -1.740845  2.455600
# 13 -0.906394 -0.368578 -0.313478  0.555289
# 14  0.865156 -0.751876  1.162484  0.133928
# 15 -2.778972 -0.482649  0.919293 -0.030589
# 16  0.312498  1.349975 -0.955233 -0.036569
# 17  0.508307  1.182560  0.993528  0.568089
# 18  0.569329 -1.387227  1.219866 -1.089318
# 19 -0.778057  2.241017 -1.644478  2.956154

# %%
# Bar Chart
my_df.abs().plot(kind="bar")
# Out:
# <Axes: >

# %%
# Bar Chart Stacked
my_df.abs().plot(kind="bar", stacked=True)
# Out:
# <Axes: >

# %%
from re import T
# Grid Lines
my_df.abs().plot(kind="bar", stacked=True, grid=True)
# Out:
# <Axes: >

# %%
# Shading
my_df.abs().plot(kind="bar", stacked=True, alpha=0.5)
# Out:
# <Axes: >

# %%
# Title
my_df.abs().plot(kind="bar", stacked=True, alpha=0.5, title="My Awesome Barchart")
# Out:
# <Axes: title={'center': 'My Awesome Barchart'}>

# %%
# Legend
my_df.abs().plot(kind="bar", stacked=True, alpha=0.5, legend=False)
# Out:
# <Axes: >

# %%
# Second Way
my_df.abs().plot.bar()
# Out:
# <Axes: >

# %%
from inspect import stack
# Second Way Stacked
my_df.abs().plot.bar(stacked=True)
# Out:
# <Axes: >

# %%
# Second Way Shading
my_df.abs().plot.bar(stacked=True, alpha=0.5)
# Out:
# <Axes: >

# %%
from numpy._core.defchararray import title
# Second Way Title
my_df.abs().plot.bar(stacked=True, alpha=0.5, title="My 2nd Bar Chart")
# Out:
# <Axes: title={'center': 'My 2nd Bar Chart'}>

# %%
# Second Way Legend
my_df.abs().plot.bar(stacked=True, alpha=0.5, title="My 2nd Bar Chart", legend=False)
# Out:
# <Axes: title={'center': 'My 2nd Bar Chart'}>

# %%
# Second Way Grid Lines
my_df.abs().plot.bar(stacked=True, alpha=0.5, grid=True)
# Out:
# <Axes: >

# %%
# Line Charts
my_df.abs().plot(kind="line")
# Out:
# <Axes: >

# %%
# Line Width
my_df.abs().plot(kind="line", lw=2)
# Out:
# <Axes: >

# %%
# Line Single
my_df['Mon'].abs().plot(kind="line")
# Out:
# <Axes: >

# %%
# Line more than one
my_df[['Mon', 'Tues']].abs().plot(kind="line")
# Out:
# <Axes: >

# %%
# Size
my_df.abs().plot(kind="line", figsize=(10, 5))
# Out:
# <Axes: >

# %%
# Title
my_df.abs().plot(kind="line", title="My Not Awesome Line Chart")
# Out:
# <Axes: title={'center': 'My Not Awesome Line Chart'}>

# %%
# Shading
my_df.abs().plot(kind="line", alpha=0.6)
# Out:
# <Axes: >

# %%
# Legend
my_df.abs().plot(kind="line", legend=False)
# Out:
# <Axes: >

# %%
# Second Way Line Charts
my_df.abs().plot.line(lw=3)
# Out:
# <Axes: >

# %%
my_df = pd.DataFrame(randn(500, 4), columns=["Mon", "Tues", "Wed", "Thur"])
my_df
# Out:
#           Mon      Tues       Wed      Thur
# 0   -0.307933 -0.674405  0.343643 -0.615957
# 1   -1.413996 -0.944590  0.729765 -1.149966
# 2    0.285894  0.907180 -0.212004 -1.226126
# 3   -1.749495 -1.172980 -1.651460  1.273697
# 4    0.154329  0.791336 -0.849369 -0.420690
# ..        ...       ...       ...       ...
# 495  1.370085  0.914600 -0.741688  0.176188
# 496 -1.442528  1.490761  0.002785 -0.005444
# 497 -0.934732 -0.243314 -1.541633  0.090951
# 498 -0.009892  0.019714 -1.891054 -0.106709
# 499  0.756176  0.142363  0.884577  0.454088
#
# [500 rows x 4 columns]

# %%
# Scatterplots
my_df.plot(kind="scatter", x="Mon", y="Tues")
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# Add third variable weight
my_df.plot(kind="scatter", x="Mon", y="Tues", c="Wed")
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# Add Colors   https://matplotlib.org/stable/users/explain/colors/colormaps.html
my_df.plot(kind="scatter", x="Mon", y="Tues", c="Wed", cmap="magma")
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# By Size
my_df.plot(kind="scatter", x="Mon", y="Tues", s=my_df["Wed"]*100, cmap="seismic")
# Out:
# /usr/local/lib/python3.12/dist-packages/matplotlib/collections.py:1008: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# /usr/local/lib/python3.12/dist-packages/pandas/plotting/_matplotlib/core.py:1345: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# By Size easier to read with Alpha
my_df.plot(kind="scatter", x="Mon", y="Tues", s=my_df["Wed"]*100, cmap="seismic", alpha=0.3)
# Out:
# /usr/local/lib/python3.12/dist-packages/matplotlib/collections.py:1008: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# /usr/local/lib/python3.12/dist-packages/pandas/plotting/_matplotlib/core.py:1345: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# Title Etc
my_df.plot(kind="scatter", x="Mon", y="Tues", s=my_df["Wed"]*100, cmap="seismic", alpha=0.3, title="My Groovy Scatterplot")
# Out:
# /usr/local/lib/python3.12/dist-packages/matplotlib/collections.py:1008: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# /usr/local/lib/python3.12/dist-packages/pandas/plotting/_matplotlib/core.py:1345: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: title={'center': 'My Groovy Scatterplot'}, xlabel='Mon', ylabel='Tues'>

# %%
# Boxplots
my_df.plot(kind="box")
# Out:
# <Axes: >

# %%
# Size
my_df.plot(kind="box", figsize=(10, 5))
# Out:
# <Axes: >

# %%
# Boxplot Color
my_df.plot(kind="box", figsize=(10, 5), cmap="bwr")
# Out:
# <Axes: >

# %%
# No Legend
my_df.plot(kind="box", figsize=(10, 5), cmap="bwr", legend=False)
# Out:
# <Axes: >

# %%
# Grid
my_df.plot(kind="box", figsize=(10, 5), cmap="bwr", grid=True)
# Out:
# <Axes: >

# %%
# Title stuff
my_df.plot(kind="box", figsize=(10, 5), cmap="bwr", title="Whiskers!")
# Out:
# <Axes: title={'center': 'Whiskers!'}>

# %%
# Other Way
my_df.plot.box()
# Out:
# <Axes: >

# %%
# Hexplots
my_df.plot(kind="hexbin", x="Mon", y="Tues")
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# Gridsize
my_df.plot(kind="hexbin", x="Mon", y="Tues", gridsize=10)
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# C
my_df.plot(kind="hexbin", x="Mon", y="Tues", C="Wed", gridsize=10)
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# Color
my_df.plot(kind="hexbin", x="Mon", y="Tues", gridsize=10, cmap="jet")
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# Gridsize
my_df.plot(kind="hexbin", x="Mon", y="Tues", gridsize=10, grid=True)
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# Title
my_df.plot(kind="hexbin", x="Mon", y="Tues", gridsize=10, title="My Hexy!")
# Out:
# <Axes: title={'center': 'My Hexy!'}, xlabel='Mon', ylabel='Tues'>

# %%
# Other Method
my_df.plot.hexbin(x="Mon", y="Thur", gridsize=10)
# Out:
# <Axes: xlabel='Mon', ylabel='Thur'>

# %%
# Density and KDE Plots (Kernal Density Plots)
my_df.plot(kind="kde", alpha=0.5, grid=True)
# Out:
# <Axes: ylabel='Density'>

# %%
# Second way
my_df.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
# Density Plot
my_df.plot(kind="density", alpha=0.5, grid=True)
# Out:
# <Axes: ylabel='Density'>

# %%
# Second way
my_df.plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
# Tile Grid etc
my_df.plot.density(title="Terrible Densities", legend=True)
# Out:
# <Axes: title={'center': 'Terrible Densities'}, ylabel='Density'>
