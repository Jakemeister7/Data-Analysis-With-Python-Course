# %% [markdown]
# <a href="https://colab.research.google.com/github/Jakemeister7/Data-Analysis-With-Python-Course/blob/main/Matplotlib_1_Histograms_and_Area_Plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Charts and Graphs with Matplotlib

# %%
import pandas as pd
import numpy as np
from numpy.random import randn
# %matplotlib inline

# %%
# Create Random Number DataFrame
my_df = pd.DataFrame(randn(100, 4), columns=["Mon", "Tues", "Wed", "Thur"])
my_df
# Out:
#          Mon      Tues       Wed      Thur
# 0   1.298195 -1.583822  1.431592  1.382337
# 1   0.125556  1.336147 -0.765169  0.551437
# 2  -0.138719  0.439751  0.912390  1.808724
# 3   0.378846 -0.532853  0.081804  0.645793
# 4  -1.182124  1.349848  0.870843  3.405500
# ..       ...       ...       ...       ...
# 95 -1.125905 -0.846892 -0.884059  1.683248
# 96  1.274774 -0.676451  1.167067 -1.469844
# 97  1.811623  0.852716 -0.941592  0.494368
# 98 -0.172177 -1.172570  0.162158  0.983733
# 99 -1.155966  1.702219 -0.899998  1.183247
#
# [100 rows x 4 columns]

# %%
# Histogram
my_df["Wed"].hist()
# Out:
# <Axes: >

# %%
# Histogram with smaller bins, 50, 20
my_df["Wed"].hist(bins=20)
# Out:
# <Axes: >

# %%
# Second Method to create Histograms
my_df["Wed"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Original method without gridlines
my_df["Wed"].hist(bins=20, grid=False)
# Out:
# <Axes: >

# %%
# Add a Legend
my_df["Wed"].hist(bins=20, grid=False, legend=True)
# Out:
# <Axes: >

# %%
# Area Plots
# Create Random Number DataFrame
my_df = pd.DataFrame(randn(20, 4), columns=["Mon", "Tues", "Wed", "Thur"])
my_df
# Out:
#          Mon      Tues       Wed      Thur
# 0  -0.832224  0.100766  0.307370 -0.912491
# 1   0.166036 -0.202660  0.791805 -0.071208
# 2  -0.660364  2.104322  0.598000  1.452449
# 3   1.263156  0.448495  0.045137  0.966808
# 4  -0.741905 -0.092707 -1.466948 -0.561267
# 5   1.339396  0.506749 -0.798488  0.767900
# 6  -0.107915 -1.545441 -0.278198  1.582249
# 7  -1.542275 -0.425192 -0.834984  0.595373
# 8  -0.134667  0.401235  1.505793 -0.421875
# 9  -0.094120 -0.064167 -0.458073  0.275965
# 10 -0.417247  0.846693 -0.573825  1.541160
# 11 -0.747340  0.468871 -1.398095 -0.779383
# 12  2.787185  1.728038 -0.575795  0.693344
# 13 -0.558355  1.340558  1.795445 -2.315337
# 14 -0.191727  0.421381 -0.311319  0.494375
# 15  0.157137  0.041015  0.947339  0.039918
# 16 -0.620084 -0.025253  0.013083 -1.322352
# 17  0.727536 -1.795101  0.401749  0.180495
# 18  0.728180  0.356721 -0.913758 -1.896169
# 19 -0.007390  0.907174 -2.059461 -0.341282

# %%
# Create Area Plot
my_df.plot(kind="area", stacked=False)
# Out:
# <Axes: >

# %%
# Absolute Values
my_df.abs().plot(kind="area")
# Out:
# <Axes: >

# %%
# Shading
my_df.abs().plot(kind="area", alpha=0.3) # Closer to 0 is more transparent
# Out:
# <Axes: >

# %%
# Title
my_df.abs().plot(kind="area", alpha=0.3, title="My Very Cool Area Plot")
# Out:
# <Axes: title={'center': 'My Very Cool Area Plot'}>

# %%
# Remove Legend
my_df.abs().plot(kind="area", alpha=0.3, title="My Very Cool Area Plot", legend=False)
# Out:
# <Axes: title={'center': 'My Very Cool Area Plot'}>

# %%
# Plot only one column
my_df['Mon'].abs().plot(kind="area", alpha=0.3, title="My Very Cool Area Plot")
# Out:
# <Axes: title={'center': 'My Very Cool Area Plot'}>

# %%
# Plot 2 Columns

my_df[['Mon', 'Wed']].abs().plot(kind="area", alpha=0.3, title="My Very Cool Area Plot")
# Out:
# <Axes: title={'center': 'My Very Cool Area Plot'}>

# %%
# Get info on a Function Shift Tab on the function - remove abs
my_df.plot(kind="area")

# %%
# Add Table
my_df.abs().plot(kind="area", alpha=0.3, title="My Very Cool Area Plot", legend=False, table=True)
#
# Out:
# <Axes: title={'center': 'My Very Cool Area Plot'}>
