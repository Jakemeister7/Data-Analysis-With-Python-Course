# %% [markdown]
# <a href="https://colab.research.google.com/github/Jakemeister7/Data-Analysis-With-Python-Course/blob/main/Seaborn_Charts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Seaborn Charts

# %%
import pandas as pd
import numpy as np
from numpy.random import randn
import seaborn as sns

# %%
my_df = pd.DataFrame(randn(100, 4), columns=["Mon", "Tues", "Wed", "Thur"])
my_df
# Out:
#          Mon      Tues       Wed      Thur
# 0  -0.818084 -0.639367 -1.112985  0.671304
# 1  -0.847948 -0.021902 -0.033274 -1.275934
# 2  -0.644364  0.311066  2.438476 -1.262504
# 3  -0.095365  1.022631 -0.479037  1.158170
# 4  -0.950183  1.071253  0.887873  0.652289
# ..       ...       ...       ...       ...
# 95 -1.246021 -2.176796  1.002069 -0.833731
# 96  0.446186 -0.767450  1.369641  0.799170
# 97  0.083168 -0.102484 -1.489567 -1.071918
# 98  0.120183 -0.524309  0.659384  0.705419
# 99 -0.415178  0.549246  0.811551 -0.670866
#
# [100 rows x 4 columns]

# %%
# Basic histogram
sns.histplot(data=my_df, x="Mon")
# Out:
# <Axes: xlabel='Mon', ylabel='Count'>

# %%
# Histogram with customization
sns.histplot(data=my_df, x="Mon", bins=100, color="green")
# Out:
# <Axes: xlabel='Mon', ylabel='Count'>

# %%
 # Histogram withe KDE overlay
 sns.histplot(data=my_df, x="Mon", kde=True, bins=15, color="coral")
# Out:
# <Axes: xlabel='Mon', ylabel='Count'>

# %%
# Histogram with transparency and different stat
sns.histplot(data=my_df, x="Mon", kde=True, bins=15, color="coral", alpha=0.3, stat="density")
# Out:
# <Axes: xlabel='Mon', ylabel='Density'>

# %%
# Basic bar chart (using mean values)
means = my_df.abs().mean()
days = my_df.columns
sns.barplot(x=days, y=means)
# Out:
# <Axes: xlabel='None', ylabel='None'>

# %%
# Bar chart with colors
sns.barplot(x=days, y=means, palette="coolwarm", hue=days)
# Out:
# <Axes: xlabel='None', ylabel='None'>

# %%
# Horizontal bar chart
sns.barplot(y=days, x=means, palette="coolwarm", hue=days)
# Out:
# <Axes: xlabel='None', ylabel='None'>

# %%
# Bar chart with transparency and width
sns.barplot(x=days, y=means, palette="coolwarm", hue=days, width=0.2, alpha=0.3)
# Out:
# <Axes: xlabel='None', ylabel='None'>

# %%
# Basic line chart
sns.lineplot(data=abs(my_df), x=my_df.index, y="Mon")
# Out:
# <Axes: xlabel='None', ylabel='Mon'>

# %%
# Multiple lines line chart
sns.lineplot(data=abs(my_df))
# Out:
# <Axes: >

# %%
# Line chart with markers and styling
sns.lineplot(data=abs(my_df), x=my_df.index, y="Mon", marker="o",linewidth=6, color="purple")
# Out:
# <Axes: xlabel='None', ylabel='Mon'>

# %%
# Line chart with transparency
sns.lineplot(data=abs(my_df), x=my_df.index, y="Mon", marker="o",linewidth=2, color="purple", alpha=0.3)
# Out:
# <Axes: xlabel='None', ylabel='Mon'>

# %%
# Basic scatterplot
sns.scatterplot(data=my_df, x="Mon", y="Tues")
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# Scatterplot with color and size
sns.scatterplot(data=my_df, x="Mon", y="Tues", color="red", s=100)
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# Scatterplot with hue (color by values)
sns.scatterplot(data=my_df, x="Mon", y="Tues", hue=my_df["Mon"], palette="viridis")
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# Scatterplot with size based on values and transparency
sns.scatterplot(data=my_df, x="Mon", y="Tues", hue=my_df["Mon"], palette="viridis", alpha=0.3, sizes=(20, 200), size=abs(my_df['Tues']))
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# Basic boxplot
sns.boxplot(data=my_df)
# Out:
# <Axes: >

# %%
# Boxplot with colors
sns.boxplot(data=my_df, palette="Set2")
# Out:
# <Axes: >

# %%
# Horizontal boxplot
sns.boxplot(data=my_df, orient="h", palette="Set2")
# Out:
# <Axes: >

# %%
# Boxplot with custom width and without outliers
sns.boxplot(data=my_df, palette="Set2", showfliers=False)
# Out:
# <Axes: >

# %%
# Basic KDE plot
sns.kdeplot(data=my_df, x="Mon", fill=True)
# Out:
# <Axes: xlabel='Mon', ylabel='Density'>

# %%
# Multiple KDE plots
sns.kdeplot(data=my_df, x="Mon", fill=True, label="Mon")
sns.kdeplot(data=my_df, x="Tues", fill=True, label="Tues")
# Out:
# <Axes: xlabel='Mon', ylabel='Density'>

# %%
# KDE plot with bandwidth adjustment (smoother)
sns.kdeplot(data=my_df, x="Mon", fill=True, label="Mon",bw_adjust=2, alpha=0.2)
# Out:
# <Axes: xlabel='Mon', ylabel='Density'>

# %%
# KDE plot with different bandwidth (rougher) and linewidth
sns.kdeplot(data=my_df, x="Mon", fill=True, label="Mon", bw_adjust=0.5, alpha=0.3, linewidth=3, color="purple")
# Out:
# <Axes: xlabel='Mon', ylabel='Density'>
